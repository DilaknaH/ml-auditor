# %%
# %pip install pandas scikit-learn

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# 1. LEAKAGE BUG: Fit on whole dataset
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X) # <--- BUG: Should be done after split

# 2. REPRODUCIBILITY BUG: No random state
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y) # <--- BUG: missing random_state

# 3. MODEL BUG: No random state
model = RandomForestClassifier() 
model.fit(X_train, y_train)

# 4. METRIC BUG: Accuracy on potentially imbalanced data
preds = model.predict(X_test)
print(accuracy_score(y_test, preds))
