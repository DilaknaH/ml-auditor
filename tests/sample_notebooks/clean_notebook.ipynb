# %%
# %pip install pandas scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\Users\Dilakna Godagamage\Documents\Project\ml-auditor\venv\Lib\site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in c:\Users\Dilakna Godagamage\Documents\Project\ml-auditor\venv\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\Dilakna Godagamage\Documents\Project\ml-auditor\venv\Lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\Dilakna Godagamage\Documents\Project\ml-auditor\venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\Dilakna Godagamage\Documents\Project\ml-auditor\venv\Lib\site-packages (from pandas) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\Dilakna Godagamage\Documents\Project\ml-auditor\venv\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\Dilakna Godagamage\Documents\Project\ml-auditor\venv\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\Users\Dilakna Godagamage\Documents\Project\ml-auditor\venv\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\Users\Dilakna Godagamage\Documents\Project\ml-auditor\venv\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\Users\Dilakna Godagamage\Documents\Project\ml-auditor\venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# Correct Split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# Correct Scaler Fit
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Correct Model
model = RandomForestClassifier(random_state=42)
model.fit(X_train_scaled, y_train)

# Correct Metric
preds = model.predict(X_test_scaled)
print(f1_score(y_test, preds))
